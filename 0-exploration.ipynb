# %% [markdown]
# # Testing whether we can load smirnoff99Frosst parameters...

# %% [markdown]
# ## Standard imports

# %%
import openeye
from openeye import oechem
from simtk import openmm
from simtk import unit
import numpy as np

# %% [markdown]
# ## OFF imports

# %%
from openforcefield.typing.engines.smirnoff.forcefield import ForceField, generateTopologyFromOEMol
from openforcefield.utils import get_data_filename

# %%
from openeye.oechem import *
ifs = oemolistream()

# %%
ifs = oemolistream()
ifs.open("/home/dslochower/data/projects/openforcefield/openforcefield-binding/bcd-sybyl.mol2")
# Out:
# True

# %%
mol = next(ifs.GetOEGraphMols())

# %%
mol.IsValid()
# Out:
# True

# %%
import oenotebook as oenb

# %%
oenb.draw_mol(mol)

# %%
ifs = oemolistream()
ifs.open("b-CD_heptylamine.mol2")
mol = next(ifs.GetOEGraphMols())
oenb.draw_mol(mol)
